# %% [markdown]
# # 03 — Q-Learning Evaluation Summary
#
# Inspect saved evaluation metrics for the Q-learning agent.

# %%
import pandas as pd

summary = pd.read_csv('../data/evaluation_summary.csv')
summary
