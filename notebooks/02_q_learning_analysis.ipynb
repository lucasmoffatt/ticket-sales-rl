# %% [markdown]
# # 02 — Q-Learning Analysis
#
# Load the trained Q-learning agent and inspect its policy heatmap.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..') / 'src'))

from agents.q_learning_agent import QLearningAgent
from visualization.plots import plot_policy_heatmap, plot_training_rewards

agent = QLearningAgent.load('../models/q_learning_agent.json')
plot_training_rewards(agent.training_rewards).show()
plot_policy_heatmap(agent).show()
