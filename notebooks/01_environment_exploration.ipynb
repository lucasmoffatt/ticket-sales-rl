# %% [markdown]
# # 01 — Environment Exploration
#
# Explore `DynamicPricingEnv` with a few random episodes.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..') / 'src'))

from environment.dynamic_pricing_env import DynamicPricingEnv

env = DynamicPricingEnv(seed=0)
obs, info = env.reset(seed=0)
terminated = False
total = 0.0
while not terminated:
    obs, reward, terminated, truncated, info = env.step(env.action_space.sample())
    total += info['revenue']
    print(info['price'], info['tickets_sold'], info['revenue'], info['tickets_remaining'])
print('total revenue', total)
